# %% [markdown]
# ## VISUALISASI DATA UPAH MINIMUM PROVINSI INDONESIA PADA TAHUN 2021-2024

# %% [markdown]
# ### 📊 Deskripsi Data
#
# Dataset ini berisi **Upah Minimum Provinsi Indonesia (UMP)** menurut provinsi dari tahun 2021 sampai 2024. Data mencakup:
# - Nama provinsi
# - Tahun
# - Upah minimum provinsi dalam rupiah
#
# Sumber data diperoleh dari Badan Pusat Statistik (BPS) Indonesia melalui layanan statistik.

# %% [markdown]
# #### 1. INSTALL OPENPYXL - bertujuan untuk dapat membaca file dalam bentuk excel(xlsx)

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %% [markdown]
# #### 2. IMPORT DATA

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Marcella\OneDrive\Desktop\ump_provinsi.xlsx")

print(df)
# Out:
#                      Provinsi     2021     2022     2023     2024
# 0                        Aceh  3165031  3166460  3413666  3460672
# 1              Sumatera Utara  2499423  2522610  2710494  2809915
# 2              Sumatera Barat  2484041  2512539  2742476  2811449
# 3                        Riau  2888564  2938564  3191663  3294625
# 4                       Jambi  2630162  2698941  2943033  3037121
# 5            Sumatera Selatan  3144446  3144446  3404177  3456874
# 6                    Bengkulu  2215000  2238094  2418280  2507079
# 7                     Lampung  2432002  2440486  2633285  2716497
# 8   Kepulauan Bangka Belitung  3230024  3264884  3498479  3640000
# 9              Kepulauan Riau  3005460  3050172  3279194  3402492
# 10                DKI Jakarta  4416187  4641854  4901798  5067381
# 11                 Jawa Barat  1810351  1841487  1986670  2057495
# 12                Jawa Tengah  1798979  1812935  1958170  2036947
# ...

# %% [markdown]
# #### 3. PREVIEW DATA

# %%
df.head()
# Out:
#          Provinsi     2021     2022     2023     2024
# 0            Aceh  3165031  3166460  3413666  3460672
# 1  Sumatera Utara  2499423  2522610  2710494  2809915
# 2  Sumatera Barat  2484041  2512539  2742476  2811449
# 3            Riau  2888564  2938564  3191663  3294625
# 4           Jambi  2630162  2698941  2943033  3037121

# %% [markdown]
# #### 4. VISUALISASI DATA

# %% [markdown]
# ##### A. HISTOGRAAM

# %%
df.dtypes
# Out:
# Provinsi      str
# 2021        int64
# 2022        int64
# 2023        int64
# 2024        int64
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Provinsi', 2021, 2022, 2023, 2024], dtype='object')

# %% [markdown]
# ##### HISTOGRAM 2021

# %%
plt.figure(figsize=(8,6))
plt.hist(df[2021], bins=5, edgecolor='black')
plt.title('Distribusi UMP Tahun 2021')
plt.xlabel('Upah Minimum (Rp)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ##### HISTOGRAM 2022

# %%
plt.figure(figsize=(8,6))
plt.hist(df[2022], bins=5, edgecolor='black')
plt.title('Distribusi UMP Tahun 2022')
plt.xlabel('Upah Minimum (Rp)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ##### HISTOGRAM 2023

# %%
plt.figure(figsize=(8,6))
plt.hist(df[2023], bins=5, edgecolor='black')
plt.title('Distribusi UMP Tahun 2023')
plt.xlabel('Upah Minimum (Rp)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ##### HISTOGRAM 2024

# %%
plt.figure(figsize=(8,6))
plt.hist(df[2024], bins=5, edgecolor='black')
plt.title('Distribusi UMP Tahun 2024')
plt.xlabel('Upah Minimum (Rp)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ##### HISTOGRAM SECARA KESELURUHAN 2021-2024

# %%
plt.figure(figsize=(8,6))

plt.hist(df[2021], bins=5, alpha=0.5, label='2021')
plt.hist(df[2022], bins=5, alpha=0.5, label='2022')
plt.hist(df[2023], bins=5, alpha=0.5, label='2023')
plt.hist(df[2024], bins=5, alpha=0.5, label='2024')

plt.title('Distribusi UMP 2021-2024')
plt.xlabel('Upah Minimum (Rp)')
plt.ylabel('Frekuensi')
plt.legend()
plt.show()

# %% [markdown]
# #### B. SCATTERPLOT

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.scatter(df[2021], df[2022])
plt.scatter(df[2022], df[2023])
plt.scatter(df[2023], df[2024])

plt.xlabel("UMP Tahun Sebelumnya")
plt.ylabel("UMP Tahun Berikutnya")
plt.title("Perbandingan UMP Antar Tahun")
plt.show()
