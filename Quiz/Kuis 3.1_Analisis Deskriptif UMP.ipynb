# %% [markdown]
# ## ANALISIS DESKRIPTIF DATA UPAH MINIMUM PROVINSI INDONESIA PADA TAHUN 2021-2024

# %% [markdown]
# ### 📊 Deskripsi Data
#
# Dataset ini berisi **Upah Minimum Provinsi Indonesia (UMP)** menurut provinsi dari tahun 2021 sampai 2024. Data mencakup:
# - Nama provinsi
# - Tahun
# - Upah minimum provinsi dalam rupiah
#
# Sumber data diperoleh dari Badan Pusat Statistik (BPS) Indonesia melalui layanan statistik.

# %% [markdown]
# ### 1. Import Pandas

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Marcella\OneDrive\Desktop\ump_provinsi.xlsx")

print(df)
# Out:
#                      Provinsi     2021     2022     2023     2024
# 0                        Aceh  3165031  3166460  3413666  3460672
# 1              Sumatera Utara  2499423  2522610  2710494  2809915
# 2              Sumatera Barat  2484041  2512539  2742476  2811449
# 3                        Riau  2888564  2938564  3191663  3294625
# 4                       Jambi  2630162  2698941  2943033  3037121
# 5            Sumatera Selatan  3144446  3144446  3404177  3456874
# 6                    Bengkulu  2215000  2238094  2418280  2507079
# 7                     Lampung  2432002  2440486  2633285  2716497
# 8   Kepulauan Bangka Belitung  3230024  3264884  3498479  3640000
# 9              Kepulauan Riau  3005460  3050172  3279194  3402492
# 10                DKI Jakarta  4416187  4641854  4901798  5067381
# 11                 Jawa Barat  1810351  1841487  1986670  2057495
# 12                Jawa Tengah  1798979  1812935  1958170  2036947
# ...

# %% [markdown]
# ### 2. Preview Data

# %%
df.head()
# Out:
#          Provinsi     2021     2022     2023     2024
# 0            Aceh  3165031  3166460  3413666  3460672
# 1  Sumatera Utara  2499423  2522610  2710494  2809915
# 2  Sumatera Barat  2484041  2512539  2742476  2811449
# 3            Riau  2888564  2938564  3191663  3294625
# 4           Jambi  2630162  2698941  2943033  3037121

# %% [markdown]
# ### 3. Analisis Deskriptif

# %%
print(df.columns)
# Out:
# Index(['Provinsi', 2021, 2022, 2023, 2024], dtype='object')

# %% [markdown]
# #### A. Analisis Deskriptif 2021

# %%
import numpy as np
from scipy import stats

# ambil data kolom 2021
data = df[2021].to_numpy()

mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
variance = np.var(data)
std_dev = np.std(data)

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 2687723.7647058824
# Median: 2654512.5
# Mode: ModeResult(mode=np.int64(1765000), count=np.int64(1))
# Variance: 301021135036.59174
# Standard Deviation: 548653.9301204282

# %% [markdown]
# #### B. Analisis Deskriptif 2022

# %%
# ambil data kolom 2022
data = df[2022].to_numpy()

mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
variance = np.var(data)
std_dev = np.std(data)

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 2725504.911764706
# Median: 2688902.0
# Mode: ModeResult(mode=np.int64(1812935), count=np.int64(1))
# Variance: 319589871884.551
# Standard Deviation: 565322.8032589443

# %% [markdown]
# #### C. Analisis Deskriptif 2023

# %%
# ambil data kolom 2023
data = df[2023].to_numpy()

mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
variance = np.var(data)
std_dev = np.std(data)

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 2923309.4411764704
# Median: 2907414.0
# Mode: ModeResult(mode=np.int64(1958170), count=np.int64(1))
# Variance: 351878579027.4231
# Standard Deviation: 593193.542638002

# %% [markdown]
# #### D. Analisis Deskriptif 2024

# %%
# ambil data kolom 2024
data = df[2024].to_numpy()

mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
variance = np.var(data)
std_dev = np.std(data)

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 3024731.2352941176
# Median: 2987526.5
# Mode: ModeResult(mode=np.int64(2036947), count=np.int64(1))
# Variance: 364841153427.29755
# Standard Deviation: 604020.8220146864

# %% [markdown]
# ### 4. Cek Distribusi Data

# %% [markdown]
# #### A. Data Normal

# %%
normal_data = np.random.normal(loc=50, scale=10, size=1000)

# loc: Mean dari distribusi.
# scale: Standar deviasi dari distribusi.
# size: Jumlah data yang akan dihasilkan.

# %% [markdown]
# #### - Data Normal 2021

# %%
import matplotlib.pyplot as plt

normal_data = df[2021].to_numpy()

plt.hist(normal_data, bins=10, alpha=0.7)
plt.title('Distribusi UMP 2021')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #### - Data Normal 2022

# %%
import matplotlib.pyplot as plt

normal_data = df[2022].to_numpy()

plt.hist(normal_data, bins=10, alpha=0.7)
plt.title('Distribusi UMP 2022')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #### - Data Normal 2023

# %%
import matplotlib.pyplot as plt

normal_data = df[2023].to_numpy()

plt.hist(normal_data, bins=10, alpha=0.7)
plt.title('Distribusi UMP 2023')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #### - Data Normal 2024

# %%
import matplotlib.pyplot as plt

normal_data = df[2024].to_numpy()

plt.hist(normal_data, bins=10, alpha=0.7)
plt.title('Distribusi UMP 2024')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### B. Visualisasi Data Deskriptif

# %% [markdown]
# ### - Histogram

# %% [markdown]
# #### Histogram 2021

# %%
import matplotlib.pyplot as plt

# ambil data dari kolom tahun
data = df[2021].to_numpy()

plt.hist(data, bins=10)
plt.title('Histogram Distribusi UMP 2021')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #### Histogram 2022

# %%
# ambil data dari kolom tahun
data = df[2022].to_numpy()

plt.hist(data, bins=10)
plt.title('Histogram Distribusi UMP 2022')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #### Histogram 2023

# %%
# ambil data dari kolom tahun
data = df[2023].to_numpy()

plt.hist(data, bins=10)
plt.title('Histogram Distribusi UMP 2023')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# #### Histogram 2024

# %%
# ambil data dari kolom tahun
data = df[2024].to_numpy()

plt.hist(data, bins=10)
plt.title('Histogram Distribusi UMP 2024')
plt.xlabel('Nilai UMP')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### - Boxplot

# %% [markdown]
# #### Boxplot UMP 2021 - 2024

# %%
import matplotlib.pyplot as plt

data_2021 = df[2021]
data_2022 = df[2022]
data_2023 = df[2023]
data_2024 = df[2024]

plt.boxplot([data_2021, data_2022, data_2023, data_2024],
            labels=['2021','2022','2023','2024'])

plt.title('Perbandingan Boxplot UMP 2021-2024')
plt.ylabel('Nilai UMP')
plt.show()
# Out:
# C:\Users\Marcella\AppData\Local\Temp\ipykernel_28044\3712557236.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data_2021, data_2022, data_2023, data_2024],

# %% [markdown]
# ### - QQ-Plot

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

for tahun in [2021, 2022, 2023, 2024]:
    data = df[tahun].to_numpy()
    
    stats.probplot(data, dist="norm", plot=plt)
    plt.title(f'QQ Plot UMP {tahun}')
    plt.show()

# %% [markdown]
# ### - Uji Shapiro-Wilk

# %%
from scipy.stats import shapiro

for tahun in [2021, 2022, 2023, 2024]:
    data = df[tahun].to_numpy()
    
    stat, p_value = shapiro(data)
    
    print(f"\nTahun {tahun}")
    print(f"Statistik Uji: {stat}")
    print(f"p-value: {p_value}")
    
    if p_value > 0.05:
        print("Data kemungkinan berdistribusi normal")
    else:
        print("Data tidak berdistribusi normal")
# Out:
# Tahun 2021
# Statistik Uji: 0.9532740464093136
# p-value: 0.15385489081066145
# Data kemungkinan berdistribusi normal
#
# Tahun 2022
# Statistik Uji: 0.9326468157574804
# p-value: 0.037377905260628105
# Data tidak berdistribusi normal
#
# Tahun 2023
# Statistik Uji: 0.9343304245797711
# p-value: 0.04188567413243551
# Data tidak berdistribusi normal
#
# Tahun 2024
# Statistik Uji: 0.9279401649525819
# p-value: 0.02725828657295991
# Data tidak berdistribusi normal

# %% [markdown]
# ### - Uji Anderson-Darling

# %%
from scipy.stats import anderson

for tahun in [2021, 2022, 2023, 2024]:
    data = df[tahun].to_numpy()
    
    result = anderson(data)
    
    print(f"\nTahun {tahun}")
    print(f"Statistik Uji: {result.statistic}")
    
    for i in range(len(result.critical_values)):
        sl = result.significance_level[i]
        cv = result.critical_values[i]
        
        if result.statistic < cv:
            print(f"Pada tingkat signifikansi {sl}%, data mengikuti distribusi normal")
        else:
            print(f"Pada tingkat signifikansi {sl}%, data tidak mengikuti distribusi normal")
# Out:
# Tahun 2021
# Statistik Uji: 0.32712707764063254
# Pada tingkat signifikansi 15.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 10.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 5.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 2.5%, data mengikuti distribusi normal
# Pada tingkat signifikansi 1.0%, data mengikuti distribusi normal
#
# Tahun 2022
# Statistik Uji: 0.4430240896272508
# Pada tingkat signifikansi 15.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 10.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 5.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 2.5%, data mengikuti distribusi normal
# Pada tingkat signifikansi 1.0%, data mengikuti distribusi normal
#
# Tahun 2023
# Statistik Uji: 0.470484053157314
# Pada tingkat signifikansi 15.0%, data mengikuti distribusi normal
# Pada tingkat signifikansi 10.0%, data mengikuti distribusi normal
# ...
